# %% [markdown]
# # Лабораторная работа №6
# *Вариант 2*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Задача 1
# Вычислить значение интеграла $I=\int\limits_0^2 P_m (x)dx$, где $P_m(x) = \sum\limits_{i=0}^m c_i x^i$, с помощью квадратурных формул левых прямоугольников и по формуле трапеций с точностью $ε=10^{-14}$ . Вычислить интеграл по формуле Гаусса.

# %%
# Условие
def P_m(x):
    if np

# %%
# Левые прямоугольники
def left_rect(a, b, f):
    pass
# Out:
#   Cell In[2], line 2
#     def left_rect(a, b, f)
#                           ^
# SyntaxError: expected ':'

# %% [markdown]
# # Лабораторная работа №6
# *Вариант 2*

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Markdown
import mylib

# %% [markdown]
# ## Задача 1
# Вычислить значение интеграла $I=\int\limits_0^2 P_m (x)dx$, где $P_m(x) = \sum\limits_{i=0}^m c_i x^i$, с помощью квадратурных формул левых прямоугольников и по формуле трапеций с точностью $\varepsilon = 10^{-14}$ . Вычислить интеграл по формуле Гаусса.

# %%
# Условие
coeffs = np.array([1, 0.9, 0.8, 0.7, 0, 2.2, -4.1, 0, -3.4, 3.5])

def get_polynom(coeffs=coeffs):
    coeffs = np.asarray(coeffs)
    m = len(coeffs)
    def polynom_func(x):
        x = np.asarray(x)
        if x.ndim == 0:
            x_powers = x ** np.arange(0, m)
        else:
            x_powers = x[:, np.newaxis] ** np.arange(0, m)
        return np.dot(x_powers, coeffs)
    return polynom_func

P = get_polynom() 
eps = 10**-14
a = 0
b = 2


display(Markdown(fr"""
Условие:   
$\quad\quad P_{{{len(coeffs)-1}}} = {" ".join(f"{coeffs[i]:+} x^{i}"for i in range(len(coeffs)))}$  
$\quad\quad \varepsilon = {eps}$  
$\quad\quad a = {a}$  
$\quad\quad b = {b}$  
"""))
# Out:
# Условие:
# $\quad\quad P_{10} = +1.0 x^0 +0.9 x^1 +0.8 x^2 +0.7 x^3 +0.0 x^4 +2.2 x^5 -4.1 x^6 +0.0 x^7 -3.4 x^8 +3.5 x^9$
# $\quad\quad \varepsilon = 1e-14$
# $\quad\quad a = 0$
# $\quad\quad b = 2$

# %%
# Аналитическое решение
coeffs_anti = coeffs * (1/np.arange(1, len(coeffs) + 1))
antiderivative = get_polynom(coeffs_anti) # Первообразная
I = antiderivative(b) - antiderivative(a) # Формула Ньютона Лейбница

mylib.show_large_number(f"{I:.16}", description="Аналитическое значение интеграла:")
# Out:
#     <div style="
#         background: transparent;
#         # padding:12px 16px;
#         # border-radius:10px;
#         # border-left:4px solid #00f;
#         font-family:monospace;
#         margin:0px 0;
#         box-shadow:0 2px 8px rgba(0,0,0,0.5);
#     ">
#         <div style="color:#fff; font-size:13px; margin-bottom:8px;">
#             Аналитическое значение интеграла:
#         </div>
#
#         <div style="
#             background: transparent;
#             padding:0 0;
#             border-radius:8px;
#             overflow-x:auto;
#             white-space:nowrap;
#         ">
#             <span style="font-size:16px; font-weight:bold; color:#fff;">60</span>
#             <span style="font-size:16px; font-weight:bold; color:#fff; margin:0 0px;">.</span>
#             <div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">1</span><span style="font-size:11px; color:#333; margin-top:1px;">1</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">0</span><span style="font-size:11px; color:#333; margin-top:1px;">2</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">3</span><span style="font-size:11px; color:#333; margin-top:1px;">3</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">1</span><span style="font-size:11px; color:#333; margin-top:1px;">4</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">7</span><span style="font-size:11px; color:#333; margin-top:1px;">5</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">4</span><span style="font-size:11px; color:#333; margin-top:1px;">6</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">6</span><span style="font-size:11px; color:#333; margin-top:1px;">7</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">0</span><span style="font-size:11px; color:#333; margin-top:1px;">8</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">3</span><span style="font-size:11px; color:#333; margin-top:1px;">9</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">1</span><span style="font-size:11px; color:#333; margin-top:1px;">10</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">7</span><span style="font-size:11px; color:#333; margin-top:1px;">11</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">4</span><span style="font-size:11px; color:#333; margin-top:1px;">12</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">6</span><span style="font-size:11px; color:#333; margin-top:1px;">13</span></div><div style="display:inline-flex; flex-direction:column; align-items:center; margin:0 0.5px;"><span style="font-size:16px; font-weight:bold; padding:0px 4px; border-radius:4px; color:#fff;">4</span><span style="font-size:11px; color:#333; margin-top:1px;">14</span></div>
#         </div>
#     </div>

# %%
# Вычисление количества шагов для достижения заданной точности
